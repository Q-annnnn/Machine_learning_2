# %% [markdown]
# <a href="https://colab.research.google.com/github/Q-annnnn/USTH_Machine_learning_2/blob/main/Iris_Final.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline
from sklearn.neighbors import KNeighborsClassifier
from sklearn import metrics
from sklearn import preprocessing
from sklearn.decomposition import PCA
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import normalize

# %%
df = pd.read_csv("https://archive.ics.uci.edu/ml/machine-learning-databases/iris/iris.data", names = ["sepal length", "sepal width", "petal length", "petal width", "class"])
df
# Out:
#      sepal length  sepal width  petal length  petal width           class
# 0             5.1          3.5           1.4          0.2     Iris-setosa
# 1             4.9          3.0           1.4          0.2     Iris-setosa
# 2             4.7          3.2           1.3          0.2     Iris-setosa
# 3             4.6          3.1           1.5          0.2     Iris-setosa
# 4             5.0          3.6           1.4          0.2     Iris-setosa
# ..            ...          ...           ...          ...             ...
# 145           6.7          3.0           5.2          2.3  Iris-virginica
# 146           6.3          2.5           5.0          1.9  Iris-virginica
# 147           6.5          3.0           5.2          2.0  Iris-virginica
# 148           6.2          3.4           5.4          2.3  Iris-virginica
# 149           5.9          3.0           5.1          1.8  Iris-virginica
#
# [150 rows x 5 columns]

# %%
from sklearn.preprocessing import LabelEncoder
lae= LabelEncoder()
df["class"]= lae.fit_transform(df["class"])
df
# Out:
#      sepal length  sepal width  petal length  petal width  class
# 0             5.1          3.5           1.4          0.2      0
# 1             4.9          3.0           1.4          0.2      0
# 2             4.7          3.2           1.3          0.2      0
# 3             4.6          3.1           1.5          0.2      0
# 4             5.0          3.6           1.4          0.2      0
# ..            ...          ...           ...          ...    ...
# 145           6.7          3.0           5.2          2.3      2
# 146           6.3          2.5           5.0          1.9      2
# 147           6.5          3.0           5.2          2.0      2
# 148           6.2          3.4           5.4          2.3      2
# 149           5.9          3.0           5.1          1.8      2
#
# [150 rows x 5 columns]

# %%
data = df.iloc[:,0:4]
data
# Out:
#      sepal length  sepal width  petal length  petal width
# 0             5.1          3.5           1.4          0.2
# 1             4.9          3.0           1.4          0.2
# 2             4.7          3.2           1.3          0.2
# 3             4.6          3.1           1.5          0.2
# 4             5.0          3.6           1.4          0.2
# ..            ...          ...           ...          ...
# 145           6.7          3.0           5.2          2.3
# 146           6.3          2.5           5.0          1.9
# 147           6.5          3.0           5.2          2.0
# 148           6.2          3.4           5.4          2.3
# 149           5.9          3.0           5.1          1.8
#
# [150 rows x 4 columns]

# %%
target = df.iloc[:,4:]
target
# Out:
#      class
# 0        0
# 1        0
# 2        0
# 3        0
# 4        0
# ..     ...
# 145      2
# 146      2
# 147      2
# 148      2
# 149      2
#
# [150 rows x 1 columns]

# %%
X_train, X_test, y_train, y_test = train_test_split(data, target, test_size=0.3)

# %%
X_train
# Out:
#      sepal length  sepal width  petal length  petal width
# 130           7.4          2.8           6.1          1.9
# 0             5.1          3.5           1.4          0.2
# 35            5.0          3.2           1.2          0.2
# 70            5.9          3.2           4.8          1.8
# 50            7.0          3.2           4.7          1.4
# ..            ...          ...           ...          ...
# 115           6.4          3.2           5.3          2.3
# 58            6.6          2.9           4.6          1.3
# 85            6.0          3.4           4.5          1.6
# 60            5.0          2.0           3.5          1.0
# 98            5.1          2.5           3.0          1.1
#
# [105 rows x 4 columns]

# %%
y_train = np.ravel(y_train)

# %%
knn1 = KNeighborsClassifier(n_neighbors = 3)
knn1.fit(X_train, y_train)
knn_Y_pred1 = knn1.predict(X_test)
knn_accuracy1=metrics.accuracy_score(y_test,knn_Y_pred1)
knn_accuracy_pc1=knn_accuracy1*100
print("Error on training dataset of k = ",3 , ": {:.2f}%".format(100-knn_accuracy_pc1) )
# Out:
# Error on training dataset of k =  3 : 2.22%

# %%
knnq = KNeighborsClassifier(n_neighbors = 3)
knnq.fit(X_train, y_train)
knn_Y_predq = knnq.predict(X_test)
knn_accuracyq=metrics.accuracy_score(y_test,knn_Y_predq)*100

print("Accuracy on training dataset : {:.2f}%".format(knn_accuracyq) )
# Out:
# Accuracy on training dataset : 97.78%

# %%
for i in range (1,16):
  knn = KNeighborsClassifier(n_neighbors = i)
  knn.fit(X_train, y_train)
  knn_Y_pred = knn.predict(X_test)
  knn_accuracy=metrics.accuracy_score(y_test,knn_Y_pred)
  knn_accuracy_pc=knn_accuracy*100
  print("Error on training dataset with k = ",i , ": {:.2f}%".format(100-knn_accuracy_pc) )
# Out:
# Error on training dataset with k =  1 : 0.00%
# Error on training dataset with k =  2 : 0.00%
# Error on training dataset with k =  3 : 2.22%
# Error on training dataset with k =  4 : 0.00%
# Error on training dataset with k =  5 : 2.22%
# Error on training dataset with k =  6 : 2.22%
# Error on training dataset with k =  7 : 2.22%
# Error on training dataset with k =  8 : 2.22%
# Error on training dataset with k =  9 : 2.22%
# Error on training dataset with k =  10 : 2.22%
# Error on training dataset with k =  11 : 2.22%
# Error on training dataset with k =  12 : 2.22%
# Error on training dataset with k =  13 : 2.22%
# Error on training dataset with k =  14 : 2.22%
# Error on training dataset with k =  15 : 2.22%

# %%
normalized_x = normalize(data)

# %%
n_X_train, n_X_test, n_y_train, n_y_test = train_test_split(normalized_x,target,test_size=0.3)

# %%
n_y_train = np.ravel(n_y_train)

# %%
for k in range (1,16):
  knn3 = KNeighborsClassifier(n_neighbors = k)
  knn3.fit(n_X_train, n_y_train)
  knn_Y_predn = knn3.predict(n_X_test)
  knn_accuracyn=metrics.accuracy_score(n_y_test,knn_Y_predn)
  knn_accuracy_pcn=knn_accuracyn*100
  print("Error on training dataset with k = ",k , ": {:.2f}%".format(100-knn_accuracy_pcn) )
# Out:
# Error on training dataset with k =  1 : 2.22%
# Error on training dataset with k =  2 : 4.44%
# Error on training dataset with k =  3 : 0.00%
# Error on training dataset with k =  4 : 0.00%
# Error on training dataset with k =  5 : 0.00%
# Error on training dataset with k =  6 : 0.00%
# Error on training dataset with k =  7 : 0.00%
# Error on training dataset with k =  8 : 0.00%
# Error on training dataset with k =  9 : 0.00%
# Error on training dataset with k =  10 : 0.00%
# Error on training dataset with k =  11 : 0.00%
# Error on training dataset with k =  12 : 0.00%
# Error on training dataset with k =  13 : 0.00%
# Error on training dataset with k =  14 : 0.00%
# Error on training dataset with k =  15 : 0.00%

# %%
from sklearn.preprocessing import StandardScaler
#Standardlizing features
datascaled = StandardScaler().fit_transform(data)

# %%
#PCA 2D projection
pca = PCA(n_components=2)
principalComponents = pca.fit_transform(datascaled)

principalDf = pd.DataFrame(data = principalComponents
             , columns = ['principal component 1', 'principal component 2'])

# %%
finalDf = pd.concat([principalDf, df[['class']]], axis = 1)
finalDf
# Out:
#      principal component 1  principal component 2  class
# 0                -2.264542               0.505704      0
# 1                -2.086426              -0.655405      0
# 2                -2.367950              -0.318477      0
# 3                -2.304197              -0.575368      0
# 4                -2.388777               0.674767      0
# ..                     ...                    ...    ...
# 145               1.870522               0.382822      2
# 146               1.558492              -0.905314      2
# 147               1.520845               0.266795      2
# 148               1.376391               1.016362      2
# 149               0.959299              -0.022284      2
#
# [150 rows x 3 columns]

# %%
fig = plt.figure(figsize = (8,8))
ax = fig.add_subplot(1,1,1)
ax.set_xlabel('Principal Component 1', fontsize = 15)
ax.set_ylabel('Principal Component 2', fontsize = 15)
ax.set_title('2 component PCA', fontsize = 20)

aims = [0,1,2]
colors = ['r', 'g', 'b']
for aim, color in zip(aims,colors):
    indicesToKeep = finalDf['class'] == aim
    ax.scatter(finalDf.loc[indicesToKeep, 'principal component 1']
               , finalDf.loc[indicesToKeep, 'principal component 2']
               , c = color
               , s = 50)
ax.legend(aims)
ax.grid()

# %%
pca_X_train, pca_X_test, pca_y_train, pca_y_test = train_test_split(finalDf,target,test_size=0.3)
pca_y_train = np.ravel(pca_y_train)

# %%
for j in range (1,16):
  knn4 = KNeighborsClassifier(n_neighbors = j)
  knn4.fit(pca_X_train, pca_y_train)
  knn_Y_predp = knn4.predict(pca_X_test)
  knn_accuracyp=metrics.accuracy_score(pca_y_test,knn_Y_predp)
  knn_accuracy_pcp=knn_accuracyp*100
  print("Error on training dataset of k = ",j , ": {:.2f}%".format(100-knn_accuracy_pcp) )
# Out:
# Error on training dataset of k =  1 : 0.00%
# Error on training dataset of k =  2 : 0.00%
# Error on training dataset of k =  3 : 0.00%
# Error on training dataset of k =  4 : 0.00%
# Error on training dataset of k =  5 : 0.00%
# Error on training dataset of k =  6 : 0.00%
# Error on training dataset of k =  7 : 0.00%
# Error on training dataset of k =  8 : 0.00%
# Error on training dataset of k =  9 : 0.00%
# Error on training dataset of k =  10 : 0.00%
# Error on training dataset of k =  11 : 0.00%
# Error on training dataset of k =  12 : 0.00%
# Error on training dataset of k =  13 : 0.00%
# Error on training dataset of k =  14 : 0.00%
# Error on training dataset of k =  15 : 0.00%

# %%
from sklearn.model_selection import cross_val_score
cv_scores = []
for l in range(1,16):
    knn6 = KNeighborsClassifier(n_neighbors=l)
    scores = cross_val_score(knn6, X_train, y_train, cv=10, scoring='accuracy')
    cv_scores.append((l, scores.mean()))
best_k = max(cv_scores, key=lambda x: x[1])[0]
print('Best k:', best_k)
knn5 = KNeighborsClassifier(n_neighbors=best_k)
knn5.fit(X_train, y_train)
print('Testing accuracy:', knn5.score(X_test, y_test))
# Out:
# Best k: 13
# Testing accuracy: 0.9777777777777777

# %%
ks, scores = zip(*cv_scores)
plt.plot(ks, scores)
plt.xlabel('k')
plt.ylabel('Testing accuracy')
plt.title('k-NN testing accuracy')
plt.show()

# %%
from sklearn.model_selection import LeaveOneOut
for t in range(1, 16):
  knn7 = KNeighborsClassifier(n_neighbors=t)
  loo = LeaveOneOut()
  looscores = cross_val_score(knn7, data, np.ravel(target), cv=loo)
  error = 1 - looscores.mean()
  print("Classification error of k = ", t,":", error)
# Out:
# Classification error of k =  1 : 0.040000000000000036
# Classification error of k =  2 : 0.053333333333333344
# Classification error of k =  3 : 0.040000000000000036
# Classification error of k =  4 : 0.040000000000000036
# Classification error of k =  5 : 0.033333333333333326
# Classification error of k =  6 : 0.040000000000000036
# Classification error of k =  7 : 0.033333333333333326
# Classification error of k =  8 : 0.033333333333333326
# Classification error of k =  9 : 0.033333333333333326
# Classification error of k =  10 : 0.033333333333333326
# Classification error of k =  11 : 0.026666666666666616
# Classification error of k =  12 : 0.040000000000000036
# Classification error of k =  13 : 0.033333333333333326
# Classification error of k =  14 : 0.026666666666666616
# Classification error of k =  15 : 0.026666666666666616
